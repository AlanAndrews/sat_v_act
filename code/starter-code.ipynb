# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Many colleges around the country require apllicants to submit ACT and SAT scores as criteria for admission. States have different participation rates in each of the exams i.e. most states require most of its 11th and 12th graders take one or the other exam. Most states tend to favor one exam over the other. A minority of states either use both approximately equally or have only a small number of its 11th and 12th grades students take one of the exams.
#
# Do states that opt for one exam over the other have different college outcomes?

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*
#
# sat_act_by_college.csv: Ranges of Accepted ACT & SAT Student Scores by Colleges
#
# sat_2019.csv: 2019 SAT Scores by State
#
# act_2019.csv: 2019 ACT Scores by State
#
# us-colleges-and-universities.csv -- source: https://public.opendatasoft.com/

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
nums_1 = [1 , 2 , 3, 4, 5, 6]
def mean_list(num_list):
    num_sum = 0
    for num in num_list:
        num_sum += num
    return num_sum/(len(num_list))
mean_list(nums_1)
# Out:
# 3.5

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def stand_dev(num_list):
    num_sum = 0
    mean = mean_list(num_list)
    for num in num_list:
        num_sum += (num - mean)**2
    return (num_sum/(len(num_list)))**(1/2)
stand_dev(nums_1)
# Out:
# 1.707825127659933

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:
def str_clean(num_pct):
    a = num_pct[:-1]
    return float(a)/100
  
str_clean("50.5%")
# Out:
# 0.505

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# I didn't read all the instructions before I started and did not lowercase or remove spaces in the column names in all of the dataframes
#  until further in the data cleaning process i.e. further down in the Jupyter notebook. I did most of my data cleaning before 
# lowercasing and removing spaces. 

# Code:
by_college = pd.read_csv('../data/sat_act_by_college.csv')
act_2019 = pd.read_csv('../data/act_2019.csv')
sat_2019 = pd.read_csv('../data/sat_2019.csv')
state_abbr = pd.read_csv('../data/state_abbr.csv')
by_college.head(5)
# Out:
#                  School Test Optional? Applies to Class Year(s)  \
# 0   Stanford University            Yes                     2021
# 1       Harvard College            Yes                     2021
# 2  Princeton University            Yes                     2021
# 3   Columbia University            Yes                     2021
# 4       Yale University            Yes                     2021
#
#                                       Policy Details  Number of Applicants  \
# 0  Stanford has adopted a one-year test optional ...                 47452
# 1  Harvard has adopted a one-year test optional p...                 42749
# 2  Princeton has adopted a one-year test optional...                 35370
# 3  Columbia has adopted a one-year test optional ...                 40203
# 4  Yale has adopted a one-year test optional poli...                 36844
#
#   Accept Rate SAT Total 25th-75th Percentile ACT Total 25th-75th Percentile
# ...

# %%
state_abbr = pd.read_csv('../data/state_abbr.csv')
state_abbr.head()
# Out:
#         State STATE
# 0     Alabama    AL
# 1      Alaska    AK
# 2     Arizona    AZ
# 3    Arkansas    AR
# 4  California    CA

# %%
act_2019.head(5)
# Out:
#         State  Participation  Composite
# 0     Alabama           1.00       18.9
# 1      Alaska           0.38       20.1
# 2     Arizona           0.73       19.0
# 3    Arkansas           1.00       19.3
# 4  California           0.23       22.6

# %%
sat_2019.head(5)
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
us_unis = pd.read_csv('../data/us-colleges-and-universities2.csv', delimiter =';')
us_unis.head(5)
# Out:
#                                 Geo Point  \
# 0  28.576141693000068, -81.36768715399995
# 1   40.13962069400003, -74.96301849199995
# 2                   40.615475, -73.959376
# 3   39.94044891600004, -82.94049278499995
# 4       39.813461594000046, -84.276913429
#
#                                            Geo Shape  OBJECTID  IPEDSID  \
# 0  {"coordinates": [-81.36768715399995, 28.576141...        11   133872
# 1  {"coordinates": [-74.96301849199995, 40.139620...        90   443784
# 2  {"coordinates": [-73.959376, 40.615475], "type...       202   488004
# 3  {"coordinates": [-82.94049278499995, 39.940448...       254   454236
# 4  {"coordinates": [-84.276913429, 39.81346159400...       264   206288
#
#                               NAME                    ADDRESS      CITY STATE  \
# 0          ADVENTHEALTH UNIVERSITY           671 WINYAH DRIVE   ORLANDO    FL
# 1  STRAYER UNIVERSITY-PENNSYLVANIA  3800 HORIZON BLVD STE 100   TREVOSE    PA
# ...

# %%
act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
sat_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  53 non-null     object
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB

# %%
by_college.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416 entries, 0 to 415
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   School                          416 non-null    object
#  1   Test Optional?                  416 non-null    object
#  2   Applies to Class Year(s)        390 non-null    object
#  3   Policy Details                  416 non-null    object
#  4   Number of Applicants            416 non-null    int64
#  5   Accept Rate                     416 non-null    object
#  6   SAT Total 25th-75th Percentile  416 non-null    object
#  7   ACT Total 25th-75th Percentile  416 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 26.1+ KB

# %%
by_college.columns = by_college.columns.str.lower()

# %%
state_abbr.columns = state_abbr.columns.str.lower()

# %%
act_2019.columns = act_2019.columns.str.lower()

# %%
sat_2019.columns = sat_2019.columns.str.lower()

# %%
by_college.columns = by_college.columns.str.replace(' ', '_')

# %%
by_college.head()
# etc... for the other dataframes
# Out:
#                  school test_optional? applies_to_class_year(s)  \
# 0   Stanford University            Yes                     2021
# 1       Harvard College            Yes                     2021
# 2  Princeton University            Yes                     2021
# 3   Columbia University            Yes                     2021
# 4       Yale University            Yes                     2021
#
#                                       policy_details  number_of_applicants  \
# 0  Stanford has adopted a one-year test optional ...                 47452
# 1  Harvard has adopted a one-year test optional p...                 42749
# 2  Princeton has adopted a one-year test optional...                 35370
# 3  Columbia has adopted a one-year test optional ...                 40203
# 4  Yale has adopted a one-year test optional poli...                 36844
#
#   accept_rate sat_total_25th-75th_percentile act_total_25th-75th_percentile
# ...

# %%
sat_act_2019 = pd.merge(sat_2019, act_2019, how="left", on="State", suffixes=('_SAT', '_ACT'))
# sat_act_2019 = sat_2019.merge(act_2019, left_on='State', right_on='State')

# %%
sat_act_2019[sat_act_2019['State'] == 'Puerto Rico']
# Out:
#           State Participation Rate  EBRW  Math  Total Participation  Composite
# 39  Puerto Rico                  —   483   462    944           NaN        NaN

# %%
by_college['School'] = by_college['School'].str.upper()

# %%
us_unis.rename(columns = {'NAME':'School'}, inplace = True)

# %%
states = us_unis[['School', 'STATE']]

# %%
# colleges = pd.merge(us_unis, by_college, how="outer", on="School")
colleges = pd.merge(by_college, states, how="left", on="School")

# %%
colleges.shape
# Out:
# (416, 9)

# %%
by_college.shape
# Out:
# (416, 8)

# %%
colleges.head()
# Out:
#    unnamed:_0                school applies_to_class_year(s)  \
# 0           0   STANFORD UNIVERSITY                     2021
# 1           1       HARVARD COLLEGE                     2021
# 2           2  PRINCETON UNIVERSITY                     2021
# 3           3   COLUMBIA UNIVERSITY                     2021
# 4           4       YALE UNIVERSITY                     2021
#
#                                       policy_details  number_of_applicants  \
# 0  Stanford has adopted a one-year test optional ...                 47452
# 1  Harvard has adopted a one-year test optional p...                 42749
# 2  Princeton has adopted a one-year test optional...                 35370
# 3  Columbia has adopted a one-year test optional ...                 40203
# 4  Yale has adopted a one-year test optional poli...                 36844
#
#    accept_rate state          state sat_total_25th_percentile  \
# 0        0.043    CA     California                      1440
# ...

# %%
us_unis.shape
# Out:
# (2579, 45)

# %%
colleges.to_csv('../data/file1.csv')

# %%
colleges = pd.read_csv('../data/file2.csv.csv')
colleges
# Out:
#      Unnamed: 0                                 School Test Optional?  \
# 0             0                    STANFORD UNIVERSITY            Yes
# 1             1                        HARVARD COLLEGE            Yes
# 2             2                   PRINCETON UNIVERSITY            Yes
# 3             3                    COLUMBIA UNIVERSITY            Yes
# 4             4                        YALE UNIVERSITY            Yes
# ..          ...                                    ...            ...
# 411         411  UNIVERSITY OF TEXAS RIO GRANDE VALLEY             No
# 412         412             UNIVERSITY OF SOUTH DAKOTA             No
# 413         413              UNIVERSITY OF MISSISSIPPI             No
# 414         414                  UNIVERSITY OF WYOMING             No
# 415         415            UNIVERSITY OF TEXAS EL PASO             No
#
#     Applies to Class Year(s)  \
# 0                       2021
# 1                       2021
# 2                       2021
# ...

# %%
# dictionary source https://code.activestate.com/recipes/577305-python-dictionary-of-us-states-and-territories/

states = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AS': 'American Samoa',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'GU': 'Guam',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MP': 'Northern Mariana Islands',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NA': 'National',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'PR': 'Puerto Rico',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VI': 'Virgin Islands',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
}

# %%
def convert_abbrev(abbrev):
    return states.get(abbrev, abbrev)

# %%
colleges['State'] = colleges['STATE'].apply(convert_abbrev)

# %%
colleges.head(5)
# Out:
#    unnamed:_0                school applies_to_class_year(s)  \
# 0           0   STANFORD UNIVERSITY                     2021
# 1           1       HARVARD COLLEGE                     2021
# 2           2  PRINCETON UNIVERSITY                     2021
# 3           3   COLUMBIA UNIVERSITY                     2021
# 4           4       YALE UNIVERSITY                     2021
#
#                                       policy_details  number_of_applicants  \
# 0  Stanford has adopted a one-year test optional ...                 47452
# 1  Harvard has adopted a one-year test optional p...                 42749
# 2  Princeton has adopted a one-year test optional...                 35370
# 3  Columbia has adopted a one-year test optional ...                 40203
# 4  Yale has adopted a one-year test optional poli...                 36844
#
#    accept_rate state          state sat_total_25th_percentile  \
# 0        0.043    CA     California                      1440
# ...

# %%
colleges[colleges['School'] == 'COLLEGE OF WOOSTER' ]
# Out:
#      Unnamed: 0              School Test Optional? Applies to Class Year(s)  \
# 153         153  COLLEGE OF WOOSTER            Yes   All / Permanent Policy
#
#                                         Policy Details  Number of Applicants  \
# 153  The College of Wooster offers a test optional ...                  6352
#
#     Accept Rate SAT Total 25th-75th Percentile ACT Total 25th-75th Percentile  \
# 153      54.70%                      1150-1380                          24-31
#
#     STATE State
# 153   NaN   NaN

# %%
colleges.loc[153, 'STATE'] = 'OH'

# %%
colleges.loc[153, 'State'] = 'Ohio'

# %%
colleges.groupby(['State']).describe()
# Out:
#                      Unnamed: 0                                                \
#                           count        mean         std    min     25%    50%
# State
# Alabama                     4.0  320.750000  108.115293  165.0  290.25  357.0
# Alaska                      1.0  351.000000         NaN  351.0  351.00  351.0
# Arizona                     3.0  362.000000    2.000000  360.0  361.00  362.0
# Arkansas                    3.0  298.666667   22.233608  273.0  292.00  311.0
# California                 52.0  159.730769  109.923702    0.0   76.50  141.5
# Colorado                    6.0  233.833333  138.392798   30.0  154.25  247.5
# Connecticut                 7.0  158.428571  136.177405    4.0   68.50  132.0
# Delaware                    1.0  202.000000         NaN  202.0  202.00  202.0
# District of Columbia        6.0  227.666667  173.267039   32.0   83.75  231.0
# Florida                    12.0  322.916667  115.159540   61.0  263.25  397.0
# ...

# %%
test = colleges.copy()

# %%
colleges['Test Optional?'] = colleges['Test Optional?'].str.replace("TF", "")
# ran this code multiple times to get rid of *, (TB), (TF), code was doing something wierd whenever I tried to delete (TB). 
# Either wouldn't work or would only delete the TB. I ended up having to delete one parenthesis at a time.

# %%
colleges['Test Optional?'].value_counts()
# Out:
# Yes    390
# No      26
# Name: Test Optional?, dtype: int64

# %%
colleges['Accept Rate'] =  colleges['Accept Rate'].apply(str_clean)

# %%
colleges.head()
# Out:
#    Unnamed: 0                School Test Optional? Applies to Class Year(s)  \
# 0           0   STANFORD UNIVERSITY            Yes                     2021
# 1           1       HARVARD COLLEGE            Yes                     2021
# 2           2  PRINCETON UNIVERSITY            Yes                     2021
# 3           3   COLUMBIA UNIVERSITY            Yes                     2021
# 4           4       YALE UNIVERSITY            Yes                     2021
#
#                                       Policy Details  Number of Applicants  \
# 0  Stanford has adopted a one-year test optional ...                 47452
# 1  Harvard has adopted a one-year test optional p...                 42749
# 2  Princeton has adopted a one-year test optional...                 35370
# 3  Columbia has adopted a one-year test optional ...                 40203
# 4  Yale has adopted a one-year test optional poli...                 36844
#
# ...

# %%
colleges = pd.get_dummies(colleges, columns=['Test Optional?'])

# %%
test.tail()
# Out:
#      Unnamed: 0                                 School  \
# 411         411  UNIVERSITY OF TEXAS RIO GRANDE VALLEY
# 412         412             UNIVERSITY OF SOUTH DAKOTA
# 413         413              UNIVERSITY OF MISSISSIPPI
# 414         414                  UNIVERSITY OF WYOMING
# 415         415            UNIVERSITY OF TEXAS EL PASO
#
#     Applies to Class Year(s)  \
# 411                      NaN
# 412                      NaN
# 413                      NaN
# 414                      NaN
# 415                      NaN
#
#                                         Policy Details  Number of Applicants  \
# 411  University of Texas Rio Grande Valley requires...                 10680
# 412  Unviersity of South Dakota requires either the...                  4434
# 413  Ole Miss requires either the SAT or ACT. It do...                 15371
# 414  University of Wyoming requires either the SAT ...                  5348
# ...

# %%
test = colleges.copy()

# %%
# split_ACT = colleges['ACT Total 25th-75th Percentile'].str.split('-', expand=True)
# colleges['ACT Total 25th Percentile'] = split_ACT[0]
# colleges['ACT Total 75th Percentile'] = split_ACT[1]

# %%
# split_SAT = colleges['SAT Total 25th-75th Percentile'].str.split('-', expand=True)
# colleges['SAT Total 25th Percentile'] = split_SAT[0]
# colleges['SAT Total 75th Percentile'] = split_SAT[1]

# %%
colleges.drop(columns=['SAT Total 25th-75th Percentile'], inplace=True)

# %%
colleges.columns = colleges.columns.str.replace('?', '')
# Out:
# C:\Users\andre\AppData\Local\Temp/ipykernel_40056/1790084991.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   colleges.columns = colleges.columns.str.replace('?', '')

# %%
colleges.columns = colleges.columns.str.lower()

# %%
colleges.rename(columns = {'NAME':'School'}, inplace = True)

# %%
colleges.columns.values[5] = 'state_abbrev'

# %%
colleges.drop(columns=['ACT Total 25th-75th Percentile'], inplace=True)

# %%
act_2019['Participation'] = act_2019['Participation'].apply(str_clean)

# %%
act_2019.head()
# Out:
#         state  participation  composite
# 0     Alabama           1.00       18.9
# 1      Alaska           0.38       20.1
# 2     Arizona           0.73       19.0
# 3    Arkansas           1.00       19.3
# 4  California           0.23       22.6

# %%
sat_2019.drop(index=47, axis = 0, inplace = True)
# Deleted virgin islands and puerto rico :-(

# %%
sat_2019['Participation Rate'] = sat_2019['Participation Rate'].apply(str_clean)

# %%
sat_2019.rename(columns={"participation rate": "participation"}, inplace = True)

# %%
sat_2019.head()
# Out:
#         state  participation  ebrw  math  total
# 0     Alabama           0.07   583   560   1143
# 1      Alaska           0.41   556   541   1097
# 2     Arizona           0.31   569   565   1134
# 3    Arkansas           0.06   582   559   1141
# 4  California           0.63   534   531   1065

# %%
sat_act_2019 = pd.merge(sat_2019, act_2019, how="left", on="state", suffixes=('_sat', '_act'))

# %%
sat_act_2019.head()
# Out:
#         state  participation_sat  ebrw  math  total  participation_act  \
# 0     Alabama               0.07   583   560   1143               1.00
# 1      Alaska               0.41   556   541   1097               0.38
# 2     Arizona               0.31   569   565   1134               0.73
# 3    Arkansas               0.06   582   559   1141               1.00
# 4  California               0.63   534   531   1065               0.23
#
#    composite
# 0       18.9
# 1       20.1
# 2       19.0
# 3       19.3
# 4       22.6

# %%
colleges.rename(columns = {'applies_to_class_year(s)':'applies_to_class_year'}, inplace = True)

# %%
colleges['applies_to_class_year'].value_counts()
# Out:
# Not Permanent             232
# All / Permanent Policy    158
# Name: applies_to_class_year, dtype: int64

# %%
test =colleges.copy()

# %%
# I'm sure there is a more straight forward and elegant way to go about this, but I
# want to replace the values that aren't "All / Permanent Policy" with "Not Permanent"

to_replace = ['2021', '2021 2022', '2021 2022 2023', '2021 2022 2023 2024', '2021 2022 2023 2024 2025']
new_value = 'Not Permanent'

colleges['applies_to_class_year(s)'] = colleges['applies_to_class_year(s)'].replace(to_replace, new_value)

# %%
colleges.applies_to_class_year  = colleges.applies_to_class_year.fillna('Not Permanent')

# %%
colleges['applies_to_class_year'].isnull().value_counts()
# Out:
# False    416
# Name: applies_to_class_year, dtype: int64

# %%
colleges.head().value_counts
# Out:
# <bound method DataFrame.value_counts of                  school applies_to_class_year  \
# 0   STANFORD UNIVERSITY         Not Permanent
# 1       HARVARD COLLEGE         Not Permanent
# 2  PRINCETON UNIVERSITY         Not Permanent
# 3   COLUMBIA UNIVERSITY         Not Permanent
# 4       YALE UNIVERSITY         Not Permanent
#
#                                       policy_details  number_of_applicants  \
# 0  Stanford has adopted a one-year test optional ...                 47452
# 1  Harvard has adopted a one-year test optional p...                 42749
# 2  Princeton has adopted a one-year test optional...                 35370
# 3  Columbia has adopted a one-year test optional ...                 40203
# 4  Yale has adopted a one-year test optional poli...                 36844
#
#    accept_rate state_abbrev          state sat_total_25th_percentile  \
# 0        0.043           CA     California                      1440
# ...

# %%
colleges.rename(columns = {'Permanent_Test_Opt':'permanent_test_opt'}, inplace = True)

# %%
colleges.rename(columns = {'Temporary_Test_Opt':'temporary_test_opt'}, inplace = True)

# %%
colleges = pd.get_dummies(colleges, columns=['applies_to_class_year'])

# %%
colleges.head()
# Out:
#                  school                                     policy_details  \
# 0   STANFORD UNIVERSITY  Stanford has adopted a one-year test optional ...
# 1       HARVARD COLLEGE  Harvard has adopted a one-year test optional p...
# 2  PRINCETON UNIVERSITY  Princeton has adopted a one-year test optional...
# 3   COLUMBIA UNIVERSITY  Columbia has adopted a one-year test optional ...
# 4       YALE UNIVERSITY  Yale has adopted a one-year test optional poli...
#
#    number_of_applicants  accept_rate state_abbrev          state  \
# 0                 47452        0.043           CA     California
# 1                 42749        0.047           MA  Massachusetts
# 2                 35370        0.055           NJ     New Jersey
# 3                 40203        0.055           NY       New York
# 4                 36844        0.061           CT    Connecticut
#
#   sat_total_25th_percentile sat_total_75th_percentile  \
# 0                      1440                      1570
# ...

# %%
colleges['sat_total_25th_percentile']
# Out:
# 0      1440
# 1      1460
# 2      1440
# 3      1450
# 4      1460
#        ...
# 411     950
# 412     990
# 413    1050
# 414    1060
# 415     820
# Name: sat_total_25th_percentile, Length: 416, dtype: object

# %%
test2 = colleges.copy()

# %%
test['sat_total_25th_percentile'] = test['sat_total_25th_percentile'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_40056/2458770072.py in <module>
# ----> 1 test['sat_total_25th_percentile'] = test['sat_total_25th_percentile'].astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
# ...

# %%
#https://stackoverflow.com/questions/22588316/pandas-applying-regex-to-replace-values

test['sat_total_25th_percentile'] = test['sat_total_25th_percentile'].str.replace(r'\D', '', regex=True)

# %%
test['sat_total_25th_percentile'] = test['sat_total_25th_percentile'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_40056/2458770072.py in <module>
# ----> 1 test['sat_total_25th_percentile'] = test['sat_total_25th_percentile'].astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
# ...

# %%
test = test[test['sat_total_25th_percentile'] != '']

# %%
test['sat_total_25th_percentile'] = test['sat_total_25th_percentile'].astype(int)
# Out:
# C:\Users\andre\AppData\Local\Temp/ipykernel_40056/2458770072.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['sat_total_25th_percentile'] = test['sat_total_25th_percentile'].astype(int)

# %%
# this code didn't work the first two times I tried running it. Then it magically worked....
test.loc[:, 'sat_total_25th_percentile'] = test['sat_total_25th_percentile'].astype(int)

# %%
test['sat_total_25th_percentile']
# Out:
# 0      1440
# 1      1460
# 2      1440
# 3      1450
# 4      1460
#        ...
# 411     950
# 412     990
# 413    1050
# 414    1060
# 415     820
# Name: sat_total_25th_percentile, Length: 410, dtype: int32

# %%
colleges['sat_total_25th_percentile'] = colleges['sat_total_25th_percentile'].str.replace(r'\D', '', regex=True)

# %%
colleges = colleges[colleges['sat_total_25th_percentile'] != '']

# %%
colleges.loc[:, 'sat_total_25th_percentile'] = colleges['sat_total_25th_percentile'].astype(int)

# %%
colleges.loc[:, 'sat_total_75th_percentile'] = colleges['sat_total_75th_percentile'].astype(int)

# %%
colleges['act_total_25th_percentile'] = colleges['sat_total_25th_percentile'].str.replace(r'\D', '', regex=True)

# %%
colleges = colleges[colleges['act_total_25th_percentile'] != '']

# %%
colleges.loc[:, 'act_total_25th_percentile'] = colleges['act_total_25th_percentile'].astype(float)

# %%
colleges.loc[:, 'act_total_75th_percentile'] = colleges['act_total_75th_percentile'].astype(float)

# %%
colleges.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 405 entries, 0 to 415
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   school                     405 non-null    object
#  1   policy_details             405 non-null    object
#  2   number_of_applicants       405 non-null    int64
#  3   accept_rate                405 non-null    float64
#  4   state_abbrev               405 non-null    object
#  5   state                      405 non-null    object
#  6   sat_total_25th_percentile  405 non-null    int32
#  7   sat_total_75th_percentile  405 non-null    int32
#  8   act_total_25th_percentile  405 non-null    float64
#  9   act_total_75th_percentile  405 non-null    float64
#  10  test_optional_no           405 non-null    uint8
#  11  test_optional_yes          405 non-null    uint8
#  12  permanent_test_opt         405 non-null    uint8
# ...

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
# 													permanent_test_opt	temporary_test_opt
#
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|sat_act_2019|State names|
# |participation_sat|float|sat_act_2019|Participation rate in the SAT|
# |ebrw|int|sat_act_2019|EBRW score on SAT|
# |math|int|sat_act_2019|Math score on SAT|
# |total|int|sat_act_2019|Total SAT score|
# |participation_act|float|sat_act_2019|Participation rate in the ACT|
# |composite|float|sat_act_2019|Composite ACT score|
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |school|object|colleges|University name|
# |applies_to_class_year(s)|object|colleges|Year that test-optional policy applies|
# |policy_details|object|colleges|Policy details concerning test-optional policy|
# |number_of_applicants|int|colleges|NUmber of applicants to university|
# |accept_rate|float|colleges|University acceptance rate|
# |state_abbrev|object|colleges|State abbreviation|
# |state|object|colleges|Stat in which school is located|
# |sat_total_25th_percentile|int|colleges|25th percentile scored by applicants on SAT|
# |sat_total_75th_percentile|int|colleges|75th percentile scored by applicants on SAT|
# |act_total_25th_percentile|float|colleges|25th percentile scored by applicants on ACT|
# |act_total_75th_percentile|float|colleges|75th percentile scored by applicants on SAT|
# |test_optional_no|int|colleges|Binary denoting whether school is test-optional. 1 in this column means school requires test|
# |test_optional_yes|int|colleges|Binary denoting whether school is test-optional. 1 in this column means school does not require test|
# |permanent_test_opt|int|colleges|Binary denoting whether school has a permanent test-optional policy. 1 in this column means school has a permanent test optional policy|
# |temporary_test_opt|int|colleges|Binary denoting whether school has a temporary test-optional policy. 1 in this column means school has a temporary test optional policy|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
sd = stand_dev([i for i in sat_act_2019['ebrw']])
sd
# Out:
# 45.792378682545134

# %%
sd = stand_dev([i for i in sat_act_2019['math']])
sd
# Out:
# 50.78521461840036

# %%
sd = stand_dev([i for i in sat_act_2019['total']])
sd
# Out:
# 96.24027185617864

# %%
sd = stand_dev([i for i in sat_act_2019['composite']])
sd
# Out:
# 2.172901153595978

# %%
sd = stand_dev([i for i in sat_act_2019['participation_act']])
sd
# Out:
# 0.3417582373703047

# %%
sd = stand_dev([i for i in sat_act_2019['participation_sat']])
sd
# Out:
# 0.3836584048685726

# %%
sd = stand_dev([i for i in colleges['number_of_applicants']])
sd
# Out:
# 17426.638579835628

# %%
sd = stand_dev([i for i in colleges['accept_rate']])
sd
# Out:
# 0.24182623255559774

# %%
sd = stand_dev([i for i in colleges['sat_total_25th_percentile']])
sd
# Out:
# 525.3224350889684

# %%
sd = stand_dev([i for i in colleges['sat_total_75th_percentile']])
sd
# Out:
# 111.34077154127958

# %%
sd = stand_dev([i for i in colleges['act_total_25th_percentile']])
sd
# Out:
# 4.131452261611048

# %%
sd = stand_dev([i for i in colleges['act_total_75th_percentile']])
sd
# Out:
# 3.1548920842724386

# %%
sd = stand_dev([i for i in colleges['test_optional_no']])
sd
# Out:
# 0.2406615887607152

# %%
sd = stand_dev([i for i in colleges['permanent_test_opt']])
sd
# Out:
# 0.4835599330068939

# %%
#Code:

# %%
# States with highest SAT participation
sat_act_2019.sort_values(by='participation_sat', ascending=False).head(10)
# Out:
#             state  participation_sat  ebrw  math  total  participation_act  \
# 39   Rhode Island               1.00   503   492    995               0.12
# 13       Illinois               1.00   509   504   1013               0.35
# 22       Michigan               1.00   507   496   1003               0.19
# 5        Colorado               1.00   518   506   1024               0.27
# 6     Connecticut               1.00   529   516   1046               0.22
# 7        Delaware               1.00   499   486    985               0.13
# 9         Florida               1.00   516   483    999               0.54
# 12          Idaho               1.00   505   488    993               0.31
# 19          Maine               0.99   512   502   1013               0.06
# 48  West Virginia               0.99   483   460    943               0.49
#
#     composite
# 39       24.7
# 13       24.3
# 22       24.4
# 5        23.8
# 6        25.5
# 7        24.1
# 9        20.1
# 12       22.5
# ...

# %%
# States with lowest SAT participation
sat_act_2019.sort_values(by='participation_sat', ascending=True).head(10)
# Out:
#            state  participation_sat  ebrw  math  total  participation_act  \
# 34  North Dakota               0.02   627   636   1263               0.96
# 50       Wyoming               0.03   623   615   1238               1.00
# 41  South Dakota               0.03   633   635   1268               0.75
# 27      Nebraska               0.03   628   631   1260               1.00
# 49     Wisconsin               0.03   635   648   1283               1.00
# 24   Mississippi               0.03   628   608   1237               1.00
# 15          Iowa               0.03   622   622   1244               0.66
# 44          Utah               0.04   614   615   1230               1.00
# 23     Minnesota               0.04   636   648   1284               0.95
# 17      Kentucky               0.04   620   612   1232               1.00
#
#     composite
# 34       19.9
# 50       19.8
# 41       21.6
# 27       20.0
# 49       20.3
# 24       18.4
# 15       21.6
# 44       20.3
# ...

# %%
# States with highest ACT participation
sat_act_2019.sort_values(by='participation_act', ascending=False).head(20)
# Out:
#              state  participation_sat  ebrw  math  total  participation_act  \
# 0          Alabama               0.07   583   560   1143               1.00
# 17        Kentucky               0.04   620   612   1232               1.00
# 49       Wisconsin               0.03   635   648   1283               1.00
# 44            Utah               0.04   614   615   1230               1.00
# 42       Tennessee               0.07   618   602   1220               1.00
# 36        Oklahoma               0.22   490   472    963               1.00
# 35            Ohio               0.19   550   548   1097               1.00
# 33  North Carolina               0.51   554   546   1100               1.00
# 28          Nevada               0.20   580   576   1156               1.00
# 27        Nebraska               0.03   628   631   1260               1.00
# 26         Montana               0.09   603   596   1199               1.00
# ...

# %%
# States with lowest ACT participation
sat_act_2019.sort_values(by='participation_act', ascending=True).head()
# Out:
#             state  participation_sat  ebrw  math  total  participation_act  \
# 19          Maine               0.99   512   502   1013               0.06
# 39   Rhode Island               1.00   503   492    995               0.12
# 7        Delaware               1.00   499   486    985               0.13
# 29  New Hampshire               0.95   533   526   1059               0.14
# 38   Pennsylvania               0.70   545   537   1082               0.17
#
#     composite
# 19       24.3
# 39       24.7
# 7        24.1
# 29       25.0
# 38       23.6

# %%
# States with highest total SAT scores
sat_act_2019.sort_values(by='total', ascending=False).head()
# Out:
#            state  participation_sat  ebrw  math  total  participation_act  \
# 23     Minnesota               0.04   636   648   1284               0.95
# 49     Wisconsin               0.03   635   648   1283               1.00
# 41  South Dakota               0.03   633   635   1268               0.75
# 34  North Dakota               0.02   627   636   1263               0.96
# 27      Nebraska               0.03   628   631   1260               1.00
#
#     composite
# 23       21.4
# 49       20.3
# 41       21.6
# 34       19.9
# 27       20.0

# %%
# States with lowest total SAT scores
sat_act_2019.sort_values(by='total', ascending=True).head()
# Out:
#                    state  participation_sat  ebrw  math  total  \
# 48         West Virginia               0.99   483   460    943
# 36              Oklahoma               0.22   490   472    963
# 8   District of Columbia               0.94   495   480    975
# 7               Delaware               1.00   499   486    985
# 12                 Idaho               1.00   505   488    993
#
#     participation_act  composite
# 48               0.49       20.8
# 36               1.00       18.9
# 8                0.32       23.5
# 7                0.13       24.1
# 12               0.31       22.5

# %%
# States with highest total ACT scores
sat_act_2019.sort_values(by='composite', ascending=False).head()
# Out:
#             state  participation_sat  ebrw  math  total  participation_act  \
# 21  Massachusetts               0.81   559   561   1120               0.21
# 6     Connecticut               1.00   529   516   1046               0.22
# 29  New Hampshire               0.95   533   526   1059               0.14
# 39   Rhode Island               1.00   503   492    995               0.12
# 32       New York               0.79   531   533   1064               0.22
#
#     composite
# 21       25.5
# 6        25.5
# 29       25.0
# 39       24.7
# 32       24.5

# %%
# States with lowest total ACT scores
sat_act_2019.sort_values(by='composite', ascending=True).head()
# Out:
#              state  participation_sat  ebrw  math  total  participation_act  \
# 28          Nevada               0.20   580   576   1156               1.00
# 24     Mississippi               0.03   628   608   1237               1.00
# 40  South Carolina               0.68   526   504   1030               0.78
# 18       Louisiana               0.05   610   591   1200               1.00
# 0          Alabama               0.07   583   560   1143               1.00
#
#     composite
# 28       17.9
# 24       18.4
# 40       18.8
# 18       18.8
# 0        18.9

# %%
# States with participation over 50% in both ACT and SAT
sat_act_2019[sat_act_2019['participation_sat']>=.5][sat_act_2019['participation_act']>=.5]
# Out:
# C:\Users\andre\AppData\Local\Temp/ipykernel_40056/103994226.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sat_act_2019[sat_act_2019['participation_sat']>=.5][sat_act_2019['participation_act']>=.5]
#              state  participation_sat  ebrw  math  total  participation_act  \
# 9          Florida               1.00   516   483    999               0.54
# 11          Hawaii               0.54   550   550   1100               0.80
# 33  North Carolina               0.51   554   546   1100               1.00
# 40  South Carolina               0.68   526   504   1030               0.78
#
#     composite
# 9        20.1
# 11       19.0
# 33       19.0
# 40       18.8

# %%
colleges.groupby(['state']).describe()
# Out:
#                      number_of_applicants                              \
#                                     count          mean           std
# state
# Alabama                               4.0  16261.750000  16024.661252
# Alaska                                1.0   3673.000000           NaN
# Arizona                               3.0  34859.333333   7202.920958
# Arkansas                              3.0   6850.666667   9582.915231
# California                           51.0  28944.372549  28990.024886
# Colorado                              6.0  20275.500000  12426.902522
# Connecticut                           7.0  18445.714286  13473.977175
# Delaware                              1.0  27691.000000           NaN
# District of Columbia                  6.0  16060.333333  10385.855490
# Florida                              12.0  24389.166667  17817.234725
# Georgia                              12.0  13991.500000  11274.851295
# ...

# %% [markdown]
# **To-Do:** *Edit this cell with your findings on trends in the data (step 3 above).*

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
# Code
colleges.head()
# colleges.rename(columns = {'sat_total_50th_percentile\t':'sat_total_50th_percentile'}, inplace = True)
# sat_act_2019.head()
# Out:
#                  school                                     policy_details  \
# 0   STANFORD UNIVERSITY  Stanford has adopted a one-year test optional ...
# 1       HARVARD COLLEGE  Harvard has adopted a one-year test optional p...
# 2  PRINCETON UNIVERSITY  Princeton has adopted a one-year test optional...
# 3   COLUMBIA UNIVERSITY  Columbia has adopted a one-year test optional ...
# 4       YALE UNIVERSITY  Yale has adopted a one-year test optional poli...
#
#    number_of_applicants  accept_rate state_abbrev          state  \
# 0                 47452        0.043           CA     California
# 1                 42749        0.047           MA  Massachusetts
# 2                 35370        0.055           NJ     New Jersey
# 3                 40203        0.055           NY       New York
# 4                 36844        0.061           CT    Connecticut
#
#    sat_total_25th_percentile  sat_total_75th_percentile  \
# 0                       1440                       1570
# ...

# %%
sat_act_2019['composite'].max()
# Out:
# 25.5

# %%
# i end up merging my two dataframes into one and make another heatmap further down.

plt.figure(figsize =(8, 8))

sns.heatmap(colleges.corr(), annot= True);
plt.title('Heatmap of correlation between numeric features in the colleges dataframe');

# %%
sns.heatmap(sat_act_2019.corr(), annot= True);
plt.title('Heatmap of correlation between numeric features in the sat_act_2019 dataframe');

# %%
colleges.groupby('state').mean().sort_values(by='act_total_75th_percentile')
# Out:
#                       number_of_applicants  accept_rate  \
# state
# Alaska                         3673.000000     0.830000
# Nevada                        12720.000000     0.807000
# South Dakota                   4434.000000     0.864000
# New Mexico                    12281.000000     0.486000
# Hawaii                        16244.000000     0.584000
# North Dakota                   4964.000000     0.811000
# Idaho                          9429.500000     0.793000
# West Virginia                 18639.000000     0.816000
# Montana                        4445.500000     0.854500
# Arizona                       34859.333333     0.848000
# Wyoming                        5348.000000     0.960000
# Georgia                       13991.500000     0.529500
# Texas                         20535.136364     0.580909
# Wisconsin                     11278.428571     0.715714
# Michigan                      17545.000000     0.664909
# California                    28944.372549     0.488373
# ...

# %%
colleges[['test_optional_no', 'test_optional_yes', 'act_total_75th_percentile']].corr()
# Out:
#                            test_optional_no  test_optional_yes  \
# test_optional_no                    1.00000           -1.00000
# test_optional_yes                  -1.00000            1.00000
# act_total_75th_percentile          -0.11631            0.11631
#
#                            act_total_75th_percentile
# test_optional_no                            -0.11631
# test_optional_yes                            0.11631
# act_total_75th_percentile                    1.00000

# %%
plt.figure(figsize = (15,5))
plt.hist(colleges.state_abbrev.sort_values(), 50)
plt.xticks()
plt.title("Number of Schools by State")
# Out:
# Text(0.5, 1.0, 'Number of Schools by State')

# %%
sat_act_2019[sat_act_2019['total'] > 1113]
# Out:
#             state  participation_sat  ebrw  math  total  participation_act  \
# 0         Alabama               0.07   583   560   1143               1.00
# 2         Arizona               0.31   569   565   1134               0.73
# 3        Arkansas               0.06   582   559   1141               1.00
# 15           Iowa               0.03   622   622   1244               0.66
# 16         Kansas               0.04   618   623   1241               0.72
# 17       Kentucky               0.04   620   612   1232               1.00
# 18      Louisiana               0.05   610   591   1200               1.00
# 21  Massachusetts               0.81   559   561   1120               0.21
# 23      Minnesota               0.04   636   648   1284               0.95
# 24    Mississippi               0.03   628   608   1237               1.00
# 25       Missouri               0.04   622   615   1236               0.82
# ...

# %%
sns.scatterplot(x='participation_sat', y='participation_act', data=sat_act_2019);
# Out:
# <AxesSubplot:xlabel='participation_sat', ylabel='participation_act'>

# %%
plt.figure(figsize=(15, 5))
fig = sns.boxplot(data=colleges, x='state', y='sat_total_50th_percentile')
fig.set_xticklabels(fig.get_xticklabels(), rotation=60)
plt.title("50th percentile of SAT score by state");

# %%
plt.figure(figsize=(15, 5))
fig = sns.boxplot(data=colleges, x='state', y='act_total_50th_percentile')
fig.set_xticklabels(fig.get_xticklabels(), rotation=60)
plt.title("50th percentile of ACT score by state");

# %%
plt.figure(figsize=(15, 5))
# quant = sat_act_with_colleges[sat_act_with_colleges['accept_rate']]
fig = sns.barplot(data=sat_act_with_colleges, x='state', y='participation_sat')
fig.set_xticklabels(fig.get_xticklabels(), rotation=60)
plt.title("Participation rate in SAT by state");

# %%
plt.figure(figsize=(15, 5))
fig = sns.barplot(data=sat_act_2019, x='state', y='participation_act')
fig.set_xticklabels(fig.get_xticklabels(), rotation=60)
plt.title("Participation rate in ACT by state");

# %%
data4 = data[data['Embarked_S']==1]

sns.displot(
    data4, x="Age", col="Pclass", row="",
    binwidth=3, height=3, facet_kws=dict(margin_titles=True),
)

;

# %%
sns.scatterplot(x='participation_sat', y='total', data=sat_act_2019);
plt.title('Participation rate in SAT vs Total score by state');
# notice higher participation rates equals lower overall score. Same holds for ACT

# %%
sns.scatterplot(x='participation_act', y='composite', data=sat_act_2019);
plt.title('Participation rate in ACT vs Composite score by state');

# %%
sns.scatterplot(x='accept_rate', y='sat_total_75th_percentile', data=colleges)
plt.title('Aceptance rate vs 75th percentile of SAT scored by applicants to universities');

# %%
# here you can start to see that states with low participation rate in the SAT have a higher acceptance rate to their universities. 

sns.scatterplot(x='accept_rate', y='participation_sat', hue='accept_rate', data=sat_act_with_colleges)
plt.title('');

# %%
sns.scatterplot(x='accept_rate', y='participation_act', hue='accept_rate', data=sat_act_with_colleges)
plt.title('');

# %%
sns.scatterplot(x='accept_rate', y='sat_total_75th_percentile', hue='permanent_test_opt', data=colleges);
plt.title('Aceptance rate vs 75th percentile of SAT scored by applicants to universities \n with permanent test optional policies');

# %%
sns.scatterplot(x='accept_rate', y='sat_total_25th_percentile', hue='permanent_test_opt', data=colleges);
plt.title('Aceptance rate vs 25th percentile of SAT scored by applicants to universities \n with permanent test optional policies');

# %%
sns.scatterplot(x='accept_rate', y='sat_total_25th_percentile', hue='test_optional_no', data=colleges);
plt.title('Aceptance rate vs 25th percentile of SAT scored by applicants to universities \n that require test');

# %%
below_average = sat_act_with_colleges[sat_act_with_colleges['composite']<21.5]
sns.scatterplot(x='accept_rate', y='act_total_50th_percentile', hue='test_optional_no', data=sat_act_with_colleges);
plt.title('');

# %%
sat_act_with_colleges[sat_act_with_colleges['composite']<22.85]
# Out:
#              state  participation_sat  ebrw  math  total  participation_act  \
# 0          Alabama               0.07   583   560   1143               1.00
# 1           Alaska               0.41   556   541   1097               0.38
# 2          Arizona               0.31   569   565   1134               0.73
# 3         Arkansas               0.06   582   559   1141               1.00
# 4       California               0.63   534   531   1065               0.23
# 9          Florida               1.00   516   483    999               0.54
# 10         Georgia               0.71   538   519   1058               0.49
# 11          Hawaii               0.54   550   550   1100               0.80
# 12           Idaho               1.00   505   488    993               0.31
# 14         Indiana               0.66   543   537   1080               0.29
# 15            Iowa               0.03   622   622   1244               0.66
# ...

# %%
sat_act_with_colleges[sat_act_with_colleges['total']<1083]
# Out:
#                    state  participation_sat  ebrw  math  total  \
# 4             California               0.63   534   531   1065
# 5               Colorado               1.00   518   506   1024
# 6            Connecticut               1.00   529   516   1046
# 7               Delaware               1.00   499   486    985
# 8   District of Columbia               0.94   495   480    975
# 9                Florida               1.00   516   483    999
# 10               Georgia               0.71   538   519   1058
# 12                 Idaho               1.00   505   488    993
# 13              Illinois               1.00   509   504   1013
# 14               Indiana               0.66   543   537   1080
# 19                 Maine               0.99   512   502   1013
# 20              Maryland               0.82   535   523   1058
# 22              Michigan               1.00   507   496   1003
# 29         New Hampshire               0.95   533   526   1059
# ...

# %%
colleges_by_state = colleges.groupby('state').mean()

# %%
# combined the sat/act score dataframe with my colleges scores dataframe.
sat_act_with_colleges = pd.merge(sat_act_2019, colleges_by_state, how="left", on="state")

# %%
plt.figure(figsize =(12, 8))
sns.heatmap(sat_act_with_colleges.corr(), annot= True);
plt.title('Heatmap of correlation between numeric features in the sat_act_with_colleges dataframe');

# %%
sat_act_with_colleges.head()
# Out:
#         state  participation_sat  ebrw  math  total  participation_act  \
# 0     Alabama               0.07   583   560   1143               1.00
# 1      Alaska               0.41   556   541   1097               0.38
# 2     Arizona               0.31   569   565   1134               0.73
# 3    Arkansas               0.06   582   559   1141               1.00
# 4  California               0.63   534   531   1065               0.23
#
#    composite  number_of_applicants  accept_rate  sat_total_25th_percentile  \
# 0       18.9          16261.750000     0.724250                1080.000000
# 1       20.1           3673.000000     0.830000                1020.000000
# 2       19.0          34859.333333     0.848000                1093.333333
# 3       19.3           6850.666667     0.754667                1111.000000
# 4       22.6          28944.372549     0.488373                1151.980392
#
#    sat_total_75th_percentile  act_total_25th_percentile  \
# ...

# %%
sns.scatterplot(x='total', y='sat_total_25th_percentile', hue='participation_sat', data=sat_act_with_colleges);

# %%
sns.scatterplot(x='total', y='participation_sat', hue='test_optional_no', data=sat_act_with_colleges);

# %%
sns.scatterplot(x='composite', y='participation_act', hue='test_optional_no', data=sat_act_with_colleges);

# %%
plt.figure(figsize =(12, 8))
sns.scatterplot(x='composite', y='participation_act', hue='accept_rate', data=sat_act_with_colleges);
plt.title('Participation rate in ACT vs score by state \n Average acceptance rate by state shown in graduated colors');
plt.savefig('Participation_ACT.png')

# %%
plt.figure(figsize =(12, 8))
sns.scatterplot(x='total', y='participation_sat', hue='accept_rate', data=sat_act_with_colleges)
plt.title('Participation rate in SAT vs score by state \n Average acceptance rate by state shown in graduated colors');
plt.savefig('Participation_SAT.png')

# %%
high_sat =sat_act_with_colleges[sat_act_with_colleges['participation_sat'] >0.50][sat_act_with_colleges['participation_act'] <0.50]
# Out:
# C:\Users\andre\AppData\Local\Temp/ipykernel_40056/2207316873.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   high_sat =sat_act_with_colleges[sat_act_with_colleges['participation_sat'] >0.50][sat_act_with_colleges['participation_act'] <0.50]

# %%
high_sat
# Out:
#                    state  participation_sat  ebrw  math  total  \
# 4             California               0.63   534   531   1065
# 5               Colorado               1.00   518   506   1024
# 6            Connecticut               1.00   529   516   1046
# 7               Delaware               1.00   499   486    985
# 8   District of Columbia               0.94   495   480    975
# 10               Georgia               0.71   538   519   1058
# 12                 Idaho               1.00   505   488    993
# 13              Illinois               1.00   509   504   1013
# 14               Indiana               0.66   543   537   1080
# 19                 Maine               0.99   512   502   1013
# 20              Maryland               0.82   535   523   1058
# 21         Massachusetts               0.81   559   561   1120
# 22              Michigan               1.00   507   496   1003
# 29         New Hampshire               0.95   533   526   1059
# ...

# %%
sat_act_with_colleges.sort_values(by='accept_rate', ascending=False)
# Out:
#                    state  participation_sat  ebrw  math  total  \
# 50               Wyoming               0.03   623   615   1238
# 41          South Dakota               0.03   633   635   1268
# 26               Montana               0.09   603   596   1199
# 2                Arizona               0.31   569   565   1134
# 1                 Alaska               0.41   556   541   1097
# 48         West Virginia               0.99   483   460    943
# 34          North Dakota               0.02   627   636   1263
# 28                Nevada               0.20   580   576   1156
# 12                 Idaho               1.00   505   488    993
# 17              Kentucky               0.04   620   612   1232
# 3               Arkansas               0.06   582   559   1141
# 27              Nebraska               0.03   628   631   1260
# 44                  Utah               0.04   614   615   1230
# 37                Oregon               0.51   562   550   1112
# ...

# %%
high_act = sat_act_with_colleges[sat_act_with_colleges['participation_sat'] <0.50][sat_act_with_colleges['participation_act'] >0.50]
# Out:
# C:\Users\andre\AppData\Local\Temp/ipykernel_40056/2207253344.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   high_act = sat_act_with_colleges[sat_act_with_colleges['participation_sat'] <0.50][sat_act_with_colleges['participation_act'] >0.50]

# %%
high_act
# Out:
#            state  participation_sat  ebrw  math  total  participation_act  \
# 0        Alabama               0.07   583   560   1143               1.00
# 2        Arizona               0.31   569   565   1134               0.73
# 3       Arkansas               0.06   582   559   1141               1.00
# 15          Iowa               0.03   622   622   1244               0.66
# 16        Kansas               0.04   618   623   1241               0.72
# 17      Kentucky               0.04   620   612   1232               1.00
# 18     Louisiana               0.05   610   591   1200               1.00
# 23     Minnesota               0.04   636   648   1284               0.95
# 24   Mississippi               0.03   628   608   1237               1.00
# 25      Missouri               0.04   622   615   1236               0.82
# 26       Montana               0.09   603   596   1199               1.00
# 27      Nebraska               0.03   628   631   1260               1.00
# ...

# %%
plt.figure(figsize =(12, 8))
sns.scatterplot(x='total', y='participation_sat', hue='accept_rate', data=high_sat);

# %%
plt.figure(figsize =(12, 8))
sns.scatterplot(x='composite', y='participation_act', hue='accept_rate', data=high_act);

# %%
low_both =sat_act_with_colleges[sat_act_with_colleges['participation_sat'] <0.50][sat_act_with_colleges['participation_act'] <0.50]
# Out:
# C:\Users\andre\AppData\Local\Temp/ipykernel_40056/1161576825.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   low_both =sat_act_with_colleges[sat_act_with_colleges['participation_sat'] <0.50][sat_act_with_colleges['participation_act'] <0.50]

# %%
low_both
# Out:
#     state  participation_sat  ebrw  math  total  participation_act  composite  \
# 1  Alaska               0.41   556   541   1097               0.38       20.1
#
#    number_of_applicants  accept_rate  sat_total_25th_percentile  \
# 1                3673.0         0.83                     1020.0
#
#    sat_total_75th_percentile  act_total_25th_percentile  \
# 1                     1220.0                       17.0
#
#    act_total_75th_percentile  test_optional_no  test_optional_yes  \
# 1                       24.0               0.0                1.0
#
#    permanent_test_opt  temporary_test_opt  sat_total_50th_percentile  \
# 1                 1.0                 0.0                     1120.0
#
#    act_total_50th_percentile
# 1                       20.5

# %%
plt.figure(figsize =(12, 8))
sns.scatterplot(x='total', y='participation_sat', hue='accept_rate', data=low_both);

# %%
high_both =sat_act_with_colleges[sat_act_with_colleges['participation_sat'] >0.50][sat_act_with_colleges['participation_act'] >0.50]
# Out:
# C:\Users\andre\AppData\Local\Temp/ipykernel_40056/955154354.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   high_both =sat_act_with_colleges[sat_act_with_colleges['participation_sat'] >0.50][sat_act_with_colleges['participation_act'] >0.50]

# %%
plt.figure(figsize =(12, 8))
sns.scatterplot(x='total', y='participation_sat', hue='accept_rate', data=high_both);

# %%
sat_act_with_colleges.describe()
# Out:
#        participation_sat        ebrw        math        total  \
# count          51.000000   51.000000   51.000000    51.000000
# mean            0.490588  560.803922  552.196078  1113.078431
# std             0.387476   46.248035   51.290553    97.197910
# min             0.020000  483.000000  460.000000   943.000000
# 25%             0.055000  527.500000  511.500000  1038.000000
# 50%             0.540000  550.000000  546.000000  1097.000000
# 75%             0.820000  612.000000  599.000000  1210.000000
# max             1.000000  636.000000  648.000000  1284.000000
#
#        participation_act  composite  number_of_applicants  accept_rate  \
# count          51.000000  51.000000             50.000000    50.000000
# mean            0.586667  21.464706          14667.040064     0.626421
# std             0.345159   2.194523           6415.158938     0.151058
# min             0.060000  17.900000           3673.000000     0.310250
# ...

# %%
colleges.head(2)
# Out:
#                 school                                     policy_details  \
# 0  STANFORD UNIVERSITY  Stanford has adopted a one-year test optional ...
# 1      HARVARD COLLEGE  Harvard has adopted a one-year test optional p...
#
#    number_of_applicants  accept_rate state_abbrev          state  \
# 0                 47452        0.043           CA     California
# 1                 42749        0.047           MA  Massachusetts
#
#    sat_total_25th_percentile  sat_total_75th_percentile  \
# 0                       1440                       1570
# 1                       1460                       1580
#
#    act_total_25th_percentile  act_total_75th_percentile  test_optional_no  \
# 0                       32.0                       35.0                 0
# 1                       33.0                       35.0                 0
#
#    test_optional_yes  permanent_test_opt  temporary_test_opt  \
# 0                  1                   0                   1
# ...

# %%
sns.scatterplot(x='total', y='sat_total_50th_percentile', hue='test_optional_no', data=sat_act_with_colleges);

# %%
sns.pairplot(sat_act_with_colleges)
# this took about 90 seconds to run

# %%
test = colleges.copy()

# %%
# colleges[colleges['sat_total_25th_percentile'] == 11425]
# Out:
#                  school                                     policy_details  \
# 200  UNIVERSITY OF UTAH  The University of Utah has adopted a test opti...
#
#      number_of_applicants  accept_rate state_abbrev state  \
# 200                 24404        0.621           UT  Utah
#
#      sat_total_25th_percentile  sat_total_75th_percentile  \
# 200                      11425                       1380
#
#      act_total_25th_percentile  act_total_75th_percentile  test_optional_no  \
# 200                       22.0                       29.0                 0
#
#      test_optional_yes  permanent_test_opt  temporary_test_opt
# 200                  1                   0                   1

# %%
# colleges['sat_total_25th_percentile'].replace(11425, 1125, inplace=True)

# %%
# colleges['sat_total_50th_percentile	'] = (colleges['sat_total_25th_percentile'] + colleges['sat_total_75th_percentile']) / 2

# %%
# colleges['act_total_50th_percentile	'] = (colleges['act_total_25th_percentile'] + colleges['act_total_75th_percentile']) / 2

# %%
colleges.head()
# Out:
#                  school                                     policy_details  \
# 0   STANFORD UNIVERSITY  Stanford has adopted a one-year test optional ...
# 1       HARVARD COLLEGE  Harvard has adopted a one-year test optional p...
# 2  PRINCETON UNIVERSITY  Princeton has adopted a one-year test optional...
# 3   COLUMBIA UNIVERSITY  Columbia has adopted a one-year test optional ...
# 4       YALE UNIVERSITY  Yale has adopted a one-year test optional poli...
#
#    number_of_applicants  accept_rate state_abbrev          state  \
# 0                 47452        0.043           CA     California
# 1                 42749        0.047           MA  Massachusetts
# 2                 35370        0.055           NJ     New Jersey
# 3                 40203        0.055           NY       New York
# 4                 36844        0.061           CT    Connecticut
#
#    sat_total_25th_percentile  sat_total_75th_percentile  \
# 0                       1440                       1570
# ...

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# Many colleges around the country require apllicants to submit ACT and SAT scores as criteria for admission. States have different participation rates in each of the exams i.e. most states require most of its 11th and 12th graders take one or the other exam. MOst states tend to favor one exam over the other. A minority of states either use both approximately equally or have only a small number of its 11th and 12th grades students take one of the exams.
#
# THe Deparment of Education has hired me to look into whether states that opt for one exam over the other have different college outcomes.
#
# I explored three datasets, two (act_2019.csv and sat_2019.csv) containing information about state participation rate and scores on ACT and SAT for the year 2019, and another containing data on college admissions rates and scores on the SAT and ACT by applicants to those schools.
#
# I created an attribute correlation heatmap, histograms, boxplots, and various scatter plots. In them I compared trends and tendencies regarding university admissions rates with participation in the SAT and ACT. I aslo looked into whether any correlations existed between test scores and other attributes like whether most colleges in a state had a test-optional policies in place, or wheteher most colleges in a state had permanent test-optional policies.
#
# I discovered that on average, states with a lower participation rate in the SAT tend to have higher college acceptance rates. This tendency does not hold true for states that use the ACT as their college entry exams.
#
# My recommendation would be to look into factors that might be causing this tendency. Is this simply a coincidence? Could it be cause by socioeconomic factors? It is possible that on average states that use the SAT more widely than the ACT have more exclusive universities, thus a lower acceptance rate overall.

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
